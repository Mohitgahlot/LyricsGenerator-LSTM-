# %%
import tensorflow as tf

# %%
import numpy
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils
filename = "songs.txt"
raw_text = open(filename, 'r', encoding='utf-8').read()
raw_text = raw_text.lower()
chars = sorted(list(set(raw_text)))
char_to_int = dict((c, i) for i, c in enumerate(chars))
n_chars = len(raw_text)
n_vocab = len(chars)
print("Total Characters: ", n_chars)
print("Total Vocab: ", n_vocab) 
seq_length = 100
dataX = []
dataY = []
for i in range(0, n_chars - seq_length, 1):
    seq_in = raw_text[i:i + seq_length]
    seq_out = raw_text[i + seq_length]
    dataX.append([char_to_int[char] for char in seq_in])
    dataY.append(char_to_int[seq_out])
n_patterns = len(dataX)
print("Total Patterns: ", n_patterns)
X = numpy.reshape(dataX, (n_patterns, seq_length, 1))
X = X / float(n_vocab)
y = np_utils.to_categorical(dataY)
model = Sequential()
model.add(LSTM(256, input_shape=(X.shape[1], X.shape[2]),return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(256))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam')
filepath="song-weights-deep-{epoch:02d}-{loss:.4f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]
model.fit(X, y, epochs=30, batch_size=100, callbacks=callbacks_list)
# Out:
# Total Characters:  70666
# Total Vocab:  53
# Total Patterns:  70566
# Epoch 1/30
# 70566/70566 [==============================] - 450s 6ms/step - loss: 2.7921
#
# Epoch 00001: loss improved from inf to 2.79211, saving model to song-weights-deep-01-2.7921.hdf5
# Epoch 2/30
# 70566/70566 [==============================] - 452s 6ms/step - loss: 2.5490
#
# Epoch 00002: loss improved from 2.79211 to 2.54905, saving model to song-weights-deep-02-2.5490.hdf5
# Epoch 3/30
# 70566/70566 [==============================] - 463s 7ms/step - loss: 2.4907
#
# Epoch 00003: loss improved from 2.54905 to 2.49072, saving model to song-weights-deep-03-2.4907.hdf5
# Epoch 4/30
# 70566/70566 [==============================] - 542s 8ms/step - loss: 2.4417
#
# Epoch 00004: loss improved from 2.49072 to 2.44169, saving model to song-weights-deep-04-2.4417.hdf5
# Epoch 5/30
# 70566/70566 [==============================] - 477s 7ms/step - loss: 2.3862
#
# Epoch 00005: loss improved from 2.44169 to 2.38619, saving model to song-weights-deep-05-2.3862.hdf5
# Epoch 6/30
# 70566/70566 [==============================] - 475s 7ms/step - loss: 2.3167
#
# Epoch 00006: loss improved from 2.38619 to 2.31665, saving model to song-weights-deep-06-2.3167.hdf5
# Epoch 7/30
# 70566/70566 [==============================] - 493s 7ms/step - loss: 2.2345
#
# Epoch 00007: loss improved from 2.31665 to 2.23446, saving model to song-weights-deep-07-2.2345.hdf5
# Epoch 8/30
# 70566/70566 [==============================] - 488s 7ms/step - loss: 2.1441
#
# Epoch 00008: loss improved from 2.23446 to 2.14410, saving model to song-weights-deep-08-2.1441.hdf5
# Epoch 9/30
# 70566/70566 [==============================] - 486s 7ms/step - loss: 2.0573
#
# Epoch 00009: loss improved from 2.14410 to 2.05731, saving model to song-weights-deep-09-2.0573.hdf5
# Epoch 10/30
# 70566/70566 [==============================] - 504s 7ms/step - loss: 1.9625
#
# Epoch 00010: loss improved from 2.05731 to 1.96245, saving model to song-weights-deep-10-1.9625.hdf5
# Epoch 11/30
# 70566/70566 [==============================] - 457s 6ms/step - loss: 1.8713
#
# Epoch 00011: loss improved from 1.96245 to 1.87130, saving model to song-weights-deep-11-1.8713.hdf5
# Epoch 12/30
# 70566/70566 [==============================] - 423s 6ms/step - loss: 1.7821
#
# Epoch 00012: loss improved from 1.87130 to 1.78210, saving model to song-weights-deep-12-1.7821.hdf5
# Epoch 13/30
# 70566/70566 [==============================] - 416s 6ms/step - loss: 1.6945
#
# Epoch 00013: loss improved from 1.78210 to 1.69453, saving model to song-weights-deep-13-1.6945.hdf5
# Epoch 14/30
# 70566/70566 [==============================] - 414s 6ms/step - loss: 1.6177
#
# Epoch 00014: loss improved from 1.69453 to 1.61770, saving model to song-weights-deep-14-1.6177.hdf5
# Epoch 15/30
# 70566/70566 [==============================] - 417s 6ms/step - loss: 1.5385
#
# Epoch 00015: loss improved from 1.61770 to 1.53846, saving model to song-weights-deep-15-1.5385.hdf5
# Epoch 16/30
# 70566/70566 [==============================] - 412s 6ms/step - loss: 1.4684
#
# Epoch 00016: loss improved from 1.53846 to 1.46845, saving model to song-weights-deep-16-1.4684.hdf5
# Epoch 17/30
# 70566/70566 [==============================] - 411s 6ms/step - loss: 1.4090
#
# Epoch 00017: loss improved from 1.46845 to 1.40900, saving model to song-weights-deep-17-1.4090.hdf5
# Epoch 18/30
# 70566/70566 [==============================] - 411s 6ms/step - loss: 1.3491
#
# Epoch 00018: loss improved from 1.40900 to 1.34906, saving model to song-weights-deep-18-1.3491.hdf5
# Epoch 19/30
# 70566/70566 [==============================] - 413s 6ms/step - loss: 1.2935
#
# Epoch 00019: loss improved from 1.34906 to 1.29354, saving model to song-weights-deep-19-1.2935.hdf5
# Epoch 20/30
# 70566/70566 [==============================] - 411s 6ms/step - loss: 1.2438
#
# Epoch 00020: loss improved from 1.29354 to 1.24378, saving model to song-weights-deep-20-1.2438.hdf5
# Epoch 21/30
# 70566/70566 [==============================] - 406s 6ms/step - loss: 1.1924
#
# Epoch 00021: loss improved from 1.24378 to 1.19243, saving model to song-weights-deep-21-1.1924.hdf5
# Epoch 22/30
# 70566/70566 [==============================] - 402s 6ms/step - loss: 1.1486
#
# Epoch 00022: loss improved from 1.19243 to 1.14859, saving model to song-weights-deep-22-1.1486.hdf5
# Epoch 23/30
# 70566/70566 [==============================] - 448s 6ms/step - loss: 1.1022
#
# Epoch 00023: loss improved from 1.14859 to 1.10221, saving model to song-weights-deep-23-1.1022.hdf5
# Epoch 24/30
# 70566/70566 [==============================] - 444s 6ms/step - loss: 1.0700
#
# Epoch 00024: loss improved from 1.10221 to 1.07001, saving model to song-weights-deep-24-1.0700.hdf5
# Epoch 25/30
# 70566/70566 [==============================] - 454s 6ms/step - loss: 1.0333
#
# Epoch 00025: loss improved from 1.07001 to 1.03331, saving model to song-weights-deep-25-1.0333.hdf5
# Epoch 26/30
# 70566/70566 [==============================] - 451s 6ms/step - loss: 1.0029
#
# Epoch 00026: loss improved from 1.03331 to 1.00287, saving model to song-weights-deep-26-1.0029.hdf5
# Epoch 27/30
# 70566/70566 [==============================] - 445s 6ms/step - loss: 0.9673
#
# Epoch 00027: loss improved from 1.00287 to 0.96726, saving model to song-weights-deep-27-0.9673.hdf5
# Epoch 28/30
# 70566/70566 [==============================] - 466s 7ms/step - loss: 0.9400
#
# Epoch 00028: loss improved from 0.96726 to 0.93999, saving model to song-weights-deep-28-0.9400.hdf5
# Epoch 29/30
# 70566/70566 [==============================] - 456s 6ms/step - loss: 0.9090
#
# Epoch 00029: loss improved from 0.93999 to 0.90901, saving model to song-weights-deep-29-0.9090.hdf5
# Epoch 30/30
# 70566/70566 [==============================] - 557s 8ms/step - loss: 0.8892
#
# Epoch 00030: loss improved from 0.90901 to 0.88921, saving model to song-weights-deep-30-0.8892.hdf5

# %%
import sys
import numpy
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils
filename = "songs.txt"
raw_text = open(filename, 'r', encoding='utf-8').read()
raw_text = raw_text.lower()
chars = sorted(list(set(raw_text)))
char_to_int = dict((c, i) for i, c in enumerate(chars))
int_to_char = dict((i, c) for i, c in enumerate(chars))
n_chars = len(raw_text)
n_vocab = len(chars)
seq_length = 100
dataX = []
dataY = []
for i in range(0, n_chars - seq_length, 1):
        seq_in = raw_text[i:i + seq_length]
        seq_out = raw_text[i + seq_length]
        dataX.append([char_to_int[char] for char in seq_in])
        dataY.append(char_to_int[seq_out])
n_patterns = len(dataX)
print("Total Patterns: ", n_patterns)
X = numpy.reshape(dataX, (n_patterns, seq_length, 1))
X = X / float(n_vocab)
y = np_utils.to_categorical(dataY)
model = Sequential()
model.add(LSTM(256, input_shape=(X.shape[1], X.shape[2]),return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(256))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))
filename = "song-weights-deep-29-0.9090.hdf5"
model.load_weights(filename)
model.compile(loss='categorical_crossentropy', optimizer='adam')
start = numpy.random.randint(0, len(dataX)-1)
pattern = dataX[start]
print("Seed:")
print("\"", ''.join([int_to_char[value] for value in pattern]), "\"")
for i in range(100):
        x = numpy.reshape(pattern, (1, len(pattern), 1))
        x = x / float(n_vocab)
        prediction = model.predict(x, verbose=0)
        index = numpy.argmax(prediction)
        result = int_to_char[index]
        seq_in = [int_to_char[value] for value in pattern]
        sys.stdout.write(result)
        pattern.append(index)
        pattern = pattern[1:len(pattern)]
print("\nDone.")
# Out:
# Total Patterns:  70566
# Seed:
# " y hor kol kar jaa ni
# mainu pyar nahi je de sakdi
# jaa doob ke mar jaa ni
#
# o je tu karne aa haaye baby "
#  gaale gaane gaaye kaina aa gaayaan
# raane
#
# jab kat main hhi aayana hai
# seue paal galn aana aa aayage
# Done.
